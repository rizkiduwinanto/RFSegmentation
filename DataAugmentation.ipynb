# %% [markdown]
# ## Data Analysis Deep Learning in Forestry

# %%
from dataset import Dataset
import skimage as ski

# %%
INPUT_DIR = "../data/tiles/"
TARGET_DIR = "../data/masks/"

# %%
dataset = Dataset(INPUT_DIR, TARGET_DIR)

# %%
len(dataset)
# Out:
# 330

# %%
input_img, target_img = dataset[10]

# %%
input_img.shape, target_img.shape
# Out:
# ((7, 333, 333), (333, 333))

# %%
dataset.display(10, 1)

# %%
img_input_transposed = input_img.transpose(1, 2, 0)
img_input_transposed
# Out:
# array([[[376, 518, 406, ..., 483, 711, 510],
#         [406, 575, 455, ..., 519, 776, 544],
#         [417, 579, 452, ..., 519, 775, 542],
#         ...,
#         [362, 515, 371, ..., 504, 828, 561],
#         [343, 478, 338, ..., 483, 793, 532],
#         [351, 485, 349, ..., 490, 812, 546]],
#
#        [[383, 539, 431, ..., 502, 730, 528],
#         [400, 569, 453, ..., 518, 768, 543],
#         [410, 568, 444, ..., 512, 770, 536],
#         ...,
#         [349, 484, 340, ..., 473, 787, 531],
#         [351, 488, 346, ..., 484, 813, 543],
#         [363, 509, 369, ..., 504, 840, 570]],
#
#        [[407, 571, 465, ..., 534, 778, 556],
#         [404, 571, 459, ..., 527, 773, 551],
#         [400, 553, 435, ..., 504, 751, 529],
#         ...,
#         [361, 516, 373, ..., 506, 839, 566],
#         [357, 505, 361, ..., 500, 827, 561],
#         [349, 485, 341, ..., 486, 808, 546]],
#
#        ...,
#
#        [[307, 391, 256, ..., 211, 222, 125],
# ...

# %%
input_aug_img = dataset.augment(img_input_transposed)
input_aug_img.shape
# Out:
# /mnt/c/Users/rizki/Master Files/DL_in_forestry/.venv/lib/python3.10/site-packages/albumentations/core/composition.py:375: UserWarning: transforms is single transform, but a sequence is expected! Transform will be wrapped into list.
#   super().__init__(
# (333, 333, 7)

# %%
ski.io.imshow(input_aug_img[:,:,0])
# Out:
# /tmp/ipykernel_35914/1142637766.py:1: FutureWarning: `imshow` is deprecated since version 0.25 and will be removed in version 0.27. Please use `matplotlib`, `napari`, etc. to visualize images.
#   ski.io.imshow(input_aug_img[:,:,0])
# /mnt/c/Users/rizki/Master Files/DL_in_forestry/.venv/lib/python3.10/site-packages/skimage/io/_plugins/matplotlib_plugin.py:158: UserWarning: Low image data range; displaying image with stretched contrast.
#   lo, hi, cmap = _get_display_range(image)

# %%
target_aug_img = dataset.augment(target_img)
target_aug_img.shape
# Out:
# /mnt/c/Users/rizki/Master Files/DL_in_forestry/.venv/lib/python3.10/site-packages/albumentations/core/composition.py:375: UserWarning: transforms is single transform, but a sequence is expected! Transform will be wrapped into list.
#   super().__init__(
# (333, 333)

# %%
ski.io.imshow(target_aug_img)
# Out:
# /tmp/ipykernel_35914/214592982.py:1: FutureWarning: `imshow` is deprecated since version 0.25 and will be removed in version 0.27. Please use `matplotlib`, `napari`, etc. to visualize images.
#   ski.io.imshow(target_aug_img)
# /mnt/c/Users/rizki/Master Files/DL_in_forestry/.venv/lib/python3.10/site-packages/skimage/io/_plugins/matplotlib_plugin.py:158: UserWarning: Low image data range; displaying image with stretched contrast.
#   lo, hi, cmap = _get_display_range(image)

# %%
import matplotlib.pyplot as plt

# %%
input_img, target_img = dataset.augment_dataset(10)
# Out:
# /mnt/c/Users/rizki/Master Files/DL_in_forestry/.venv/lib/python3.10/site-packages/albumentations/core/composition.py:375: UserWarning: transforms is single transform, but a sequence is expected! Transform will be wrapped into list.
#   super().__init__(

# %%
input_img.shape, target_img.shape
# Out:
# ((333, 333, 7), (333, 333))

# %%
ski.io.imshow(input_img[:,:,1])
# Out:
# /tmp/ipykernel_35914/1977947355.py:1: FutureWarning: `imshow` is deprecated since version 0.25 and will be removed in version 0.27. Please use `matplotlib`, `napari`, etc. to visualize images.
#   ski.io.imshow(input_img[:,:,1])
# /mnt/c/Users/rizki/Master Files/DL_in_forestry/.venv/lib/python3.10/site-packages/skimage/io/_plugins/matplotlib_plugin.py:158: UserWarning: Low image data range; displaying image with stretched contrast.
#   lo, hi, cmap = _get_display_range(image)

# %%
import numpy as np
np.unique(target_img)
# Out:
# array([0, 1], dtype=uint8)

# %%
ski.io.imshow(target_img)
# Out:
# /tmp/ipykernel_35914/1950518827.py:1: FutureWarning: `imshow` is deprecated since version 0.25 and will be removed in version 0.27. Please use `matplotlib`, `napari`, etc. to visualize images.
#   ski.io.imshow(target_img)
# /mnt/c/Users/rizki/Master Files/DL_in_forestry/.venv/lib/python3.10/site-packages/skimage/io/_plugins/matplotlib_plugin.py:158: UserWarning: Low image data range; displaying image with stretched contrast.
#   lo, hi, cmap = _get_display_range(image)

# %%
fig, axes = plt.subplots(1, 2, figsize=(10, 10))
axes[0].imshow(input_img[:,:,1])
axes[0].set_title("Input Image")
axes[0].axis('off')
axes[1].imshow(target_img)
axes[1].set_title("Mask")
axes[1].axis('off')
plt.show()

# %%
train, test, val = dataset.train_test_val_split(val_ratio=0.1, test_ratio=0.1)

# %%
len(train)
# Out:
# 264

# %%
len(test)
# Out:
# 33

# %%
len(val)
# Out:
# 33

# %%
# dataset.create_dataloader()
